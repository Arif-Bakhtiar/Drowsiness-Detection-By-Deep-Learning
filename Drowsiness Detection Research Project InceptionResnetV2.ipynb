# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator , load_img, img_to_array, array_to_img
from keras.datasets import mnist
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, auc, roc_curve
from tensorflow.keras.applications import InceptionResNetV2  # Use Inception-ResNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Check GPU availability
print(tf.test.is_gpu_available())
print(tf.config.list_physical_devices('GPU'))
# Out:
# True
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Load the dataset and visualize images
labels = os.listdir("/kaggle/input/augmented-dataset-drowsiness-detection/train")
# Load the data using ImageDataGenerator
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=30
)
# Load the dataset and split into training and testing sets
directory = "/kaggle/input/augmented-dataset-drowsiness-detection/train"
target_size = (150, 150)
batch_size = 11600 # Adjust batch size as needed

# Load the dataset and split into training and testing sets
data = datagen.flow_from_directory(
    directory,
    target_size=target_size,
    batch_size=batch_size,  # Specify batch size here
    class_mode='categorical',
    subset='training'
)

# Split the data into training and testing sets
x, y = data.next()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Encode the labels using one-hot encoding
label_bin = LabelBinarizer()
y_train = label_bin.fit_transform(y_train)
y_test = label_bin.transform(y_test)
# Out:
# Found 11600 images belonging to 4 classes.

# %%
# Create the Inception-ResNetV2 base model
base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(150,150, 3))

# %%
# Add custom layers for classification on top of the base model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='softmax')
])

# %%
# Freeze the layers in the base model
for layer in base_model.layers:
    layer.trainable = False

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 3, 3, 1536)       54336736
#  onal)
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                98368
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 54,435,364
# Trainable params: 98,628
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
# Train the model
hist = model.fit(x_train, y_train, epochs=110, validation_data=(x_test, y_test), batch_size=45)  # Specify batch size here
# Out:
# Epoch 1/110
# 207/207 [==============================] - 43s 121ms/step - loss: 0.5872 - accuracy: 0.7056 - val_loss: 0.3782 - val_accuracy: 0.7935
# Epoch 2/110
# 207/207 [==============================] - 20s 94ms/step - loss: 0.4178 - accuracy: 0.7519 - val_loss: 0.3930 - val_accuracy: 0.7931
# Epoch 3/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.4039 - accuracy: 0.7631 - val_loss: 0.3740 - val_accuracy: 0.7698
# Epoch 4/110
# 207/207 [==============================] - 20s 94ms/step - loss: 0.3876 - accuracy: 0.7690 - val_loss: 0.3542 - val_accuracy: 0.8069
# Epoch 5/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.3863 - accuracy: 0.7708 - val_loss: 0.3475 - val_accuracy: 0.8116
# Epoch 6/110
# 207/207 [==============================] - 19s 94ms/step - loss: 0.3733 - accuracy: 0.7788 - val_loss: 0.3358 - val_accuracy: 0.8134
# Epoch 7/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.3688 - accuracy: 0.7798 - val_loss: 0.3257 - val_accuracy: 0.8345
# Epoch 8/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.3590 - accuracy: 0.7872 - val_loss: 0.3465 - val_accuracy: 0.7996
# Epoch 9/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.3662 - accuracy: 0.7891 - val_loss: 0.3289 - val_accuracy: 0.8155
# Epoch 10/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.3535 - accuracy: 0.7921 - val_loss: 0.3279 - val_accuracy: 0.8172
# Epoch 11/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.3512 - accuracy: 0.7975 - val_loss: 0.3219 - val_accuracy: 0.8272
# Epoch 12/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.3487 - accuracy: 0.7960 - val_loss: 0.3231 - val_accuracy: 0.8250
# Epoch 13/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.3452 - accuracy: 0.8023 - val_loss: 0.3154 - val_accuracy: 0.8263
# Epoch 14/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.3412 - accuracy: 0.7988 - val_loss: 0.3329 - val_accuracy: 0.8159
# Epoch 15/110
# 207/207 [==============================] - 20s 96ms/step - loss: 0.3393 - accuracy: 0.8006 - val_loss: 0.3189 - val_accuracy: 0.8328
# Epoch 16/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.3364 - accuracy: 0.8052 - val_loss: 0.3377 - val_accuracy: 0.8224
# Epoch 17/110
# 207/207 [==============================] - 20s 96ms/step - loss: 0.3411 - accuracy: 0.7957 - val_loss: 0.3261 - val_accuracy: 0.8341
# Epoch 18/110
# 207/207 [==============================] - 20s 96ms/step - loss: 0.3355 - accuracy: 0.8045 - val_loss: 0.3207 - val_accuracy: 0.8341
# Epoch 19/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.3268 - accuracy: 0.8082 - val_loss: 0.3215 - val_accuracy: 0.8379
# Epoch 20/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.3289 - accuracy: 0.8110 - val_loss: 0.3274 - val_accuracy: 0.8121
# Epoch 21/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.3270 - accuracy: 0.8184 - val_loss: 0.3128 - val_accuracy: 0.8332
# Epoch 22/110
# 207/207 [==============================] - 20s 96ms/step - loss: 0.3181 - accuracy: 0.8156 - val_loss: 0.3254 - val_accuracy: 0.8220
# Epoch 23/110
# 207/207 [==============================] - 20s 96ms/step - loss: 0.3217 - accuracy: 0.8166 - val_loss: 0.3196 - val_accuracy: 0.8315
# Epoch 24/110
# 207/207 [==============================] - 20s 94ms/step - loss: 0.3175 - accuracy: 0.8192 - val_loss: 0.3196 - val_accuracy: 0.8453
# Epoch 25/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.3111 - accuracy: 0.8266 - val_loss: 0.3175 - val_accuracy: 0.8543
# Epoch 26/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.3111 - accuracy: 0.8273 - val_loss: 0.3158 - val_accuracy: 0.8448
# Epoch 27/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.3116 - accuracy: 0.8279 - val_loss: 0.3030 - val_accuracy: 0.8491
# Epoch 28/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.3099 - accuracy: 0.8224 - val_loss: 0.3177 - val_accuracy: 0.8366
# Epoch 29/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.3174 - accuracy: 0.8199 - val_loss: 0.3070 - val_accuracy: 0.8509
# Epoch 30/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.3099 - accuracy: 0.8208 - val_loss: 0.3236 - val_accuracy: 0.8272
# Epoch 31/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.3063 - accuracy: 0.8280 - val_loss: 0.3087 - val_accuracy: 0.8547
# Epoch 32/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.3069 - accuracy: 0.8308 - val_loss: 0.3221 - val_accuracy: 0.8573
# Epoch 33/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.3049 - accuracy: 0.8265 - val_loss: 0.3049 - val_accuracy: 0.8526
# Epoch 34/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.3010 - accuracy: 0.8301 - val_loss: 0.3157 - val_accuracy: 0.8409
# Epoch 35/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.3014 - accuracy: 0.8297 - val_loss: 0.3094 - val_accuracy: 0.8578
# Epoch 36/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2936 - accuracy: 0.8330 - val_loss: 0.3092 - val_accuracy: 0.8474
# Epoch 37/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2996 - accuracy: 0.8337 - val_loss: 0.3129 - val_accuracy: 0.8569
# Epoch 38/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2965 - accuracy: 0.8341 - val_loss: 0.3150 - val_accuracy: 0.8517
# Epoch 39/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2925 - accuracy: 0.8370 - val_loss: 0.3074 - val_accuracy: 0.8582
# Epoch 40/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2922 - accuracy: 0.8400 - val_loss: 0.3071 - val_accuracy: 0.8582
# Epoch 41/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2829 - accuracy: 0.8472 - val_loss: 0.2978 - val_accuracy: 0.8625
# Epoch 42/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2980 - accuracy: 0.8377 - val_loss: 0.3007 - val_accuracy: 0.8470
# Epoch 43/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2928 - accuracy: 0.8358 - val_loss: 0.3091 - val_accuracy: 0.8509
# Epoch 44/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.2931 - accuracy: 0.8370 - val_loss: 0.3068 - val_accuracy: 0.8509
# Epoch 45/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2842 - accuracy: 0.8500 - val_loss: 0.3051 - val_accuracy: 0.8565
# Epoch 46/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2832 - accuracy: 0.8446 - val_loss: 0.3068 - val_accuracy: 0.8526
# Epoch 47/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2846 - accuracy: 0.8456 - val_loss: 0.3041 - val_accuracy: 0.8543
# Epoch 48/110
# 207/207 [==============================] - 20s 94ms/step - loss: 0.2854 - accuracy: 0.8403 - val_loss: 0.3064 - val_accuracy: 0.8526
# Epoch 49/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2821 - accuracy: 0.8427 - val_loss: 0.3161 - val_accuracy: 0.8431
# Epoch 50/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2817 - accuracy: 0.8482 - val_loss: 0.3053 - val_accuracy: 0.8552
# Epoch 51/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2806 - accuracy: 0.8453 - val_loss: 0.3170 - val_accuracy: 0.8509
# Epoch 52/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.2804 - accuracy: 0.8453 - val_loss: 0.3211 - val_accuracy: 0.8530
# Epoch 53/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2773 - accuracy: 0.8505 - val_loss: 0.3081 - val_accuracy: 0.8586
# Epoch 54/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.2770 - accuracy: 0.8445 - val_loss: 0.3115 - val_accuracy: 0.8582
# Epoch 55/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2773 - accuracy: 0.8487 - val_loss: 0.3051 - val_accuracy: 0.8591
# Epoch 56/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2667 - accuracy: 0.8543 - val_loss: 0.3019 - val_accuracy: 0.8565
# Epoch 57/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2753 - accuracy: 0.8447 - val_loss: 0.3252 - val_accuracy: 0.8509
# Epoch 58/110
# 207/207 [==============================] - 20s 94ms/step - loss: 0.2826 - accuracy: 0.8463 - val_loss: 0.3124 - val_accuracy: 0.8565
# Epoch 59/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2777 - accuracy: 0.8392 - val_loss: 0.3413 - val_accuracy: 0.8233
# Epoch 60/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2778 - accuracy: 0.8460 - val_loss: 0.3139 - val_accuracy: 0.8655
# Epoch 61/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2696 - accuracy: 0.8471 - val_loss: 0.3193 - val_accuracy: 0.8457
# Epoch 62/110
# 207/207 [==============================] - 19s 94ms/step - loss: 0.2737 - accuracy: 0.8491 - val_loss: 0.3010 - val_accuracy: 0.8569
# Epoch 63/110
# 207/207 [==============================] - 19s 94ms/step - loss: 0.2795 - accuracy: 0.8398 - val_loss: 0.3176 - val_accuracy: 0.8496
# Epoch 64/110
# 207/207 [==============================] - 19s 94ms/step - loss: 0.2668 - accuracy: 0.8509 - val_loss: 0.3142 - val_accuracy: 0.8599
# Epoch 65/110
# 207/207 [==============================] - 17s 85ms/step - loss: 0.2622 - accuracy: 0.8510 - val_loss: 0.3112 - val_accuracy: 0.8526
# Epoch 66/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2706 - accuracy: 0.8542 - val_loss: 0.3267 - val_accuracy: 0.8487
# Epoch 67/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2713 - accuracy: 0.8506 - val_loss: 0.3134 - val_accuracy: 0.8603
# Epoch 68/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2627 - accuracy: 0.8558 - val_loss: 0.3201 - val_accuracy: 0.8474
# Epoch 69/110
# 207/207 [==============================] - 19s 94ms/step - loss: 0.2655 - accuracy: 0.8586 - val_loss: 0.3321 - val_accuracy: 0.8595
# Epoch 70/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2518 - accuracy: 0.8667 - val_loss: 0.3279 - val_accuracy: 0.8621
# Epoch 71/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.2700 - accuracy: 0.8489 - val_loss: 0.3086 - val_accuracy: 0.8586
# Epoch 72/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2691 - accuracy: 0.8544 - val_loss: 0.3156 - val_accuracy: 0.8595
# Epoch 73/110
# 207/207 [==============================] - 18s 88ms/step - loss: 0.2754 - accuracy: 0.8495 - val_loss: 0.3233 - val_accuracy: 0.8595
# Epoch 74/110
# 207/207 [==============================] - 20s 96ms/step - loss: 0.2754 - accuracy: 0.8484 - val_loss: 0.3387 - val_accuracy: 0.8586
# Epoch 75/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.2708 - accuracy: 0.8510 - val_loss: 0.3222 - val_accuracy: 0.8616
# Epoch 76/110
# 207/207 [==============================] - 18s 88ms/step - loss: 0.2544 - accuracy: 0.8556 - val_loss: 0.3446 - val_accuracy: 0.8379
# Epoch 77/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2694 - accuracy: 0.8471 - val_loss: 0.3218 - val_accuracy: 0.8578
# Epoch 78/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2519 - accuracy: 0.8619 - val_loss: 0.3200 - val_accuracy: 0.8608
# Epoch 79/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2566 - accuracy: 0.8587 - val_loss: 0.3319 - val_accuracy: 0.8608
# Epoch 80/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2627 - accuracy: 0.8617 - val_loss: 0.3231 - val_accuracy: 0.8591
# Epoch 81/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2685 - accuracy: 0.8513 - val_loss: 0.3070 - val_accuracy: 0.8565
# Epoch 82/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2559 - accuracy: 0.8596 - val_loss: 0.3178 - val_accuracy: 0.8664
# Epoch 83/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2560 - accuracy: 0.8596 - val_loss: 0.3027 - val_accuracy: 0.8664
# Epoch 84/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2567 - accuracy: 0.8592 - val_loss: 0.3183 - val_accuracy: 0.8427
# Epoch 85/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2590 - accuracy: 0.8558 - val_loss: 0.3235 - val_accuracy: 0.8530
# Epoch 86/110
# 207/207 [==============================] - 20s 94ms/step - loss: 0.2449 - accuracy: 0.8685 - val_loss: 0.3263 - val_accuracy: 0.8681
# Epoch 87/110
# 207/207 [==============================] - 19s 94ms/step - loss: 0.2418 - accuracy: 0.8677 - val_loss: 0.3245 - val_accuracy: 0.8664
# Epoch 88/110
# 207/207 [==============================] - 20s 94ms/step - loss: 0.2503 - accuracy: 0.8657 - val_loss: 0.3201 - val_accuracy: 0.8655
# Epoch 89/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2508 - accuracy: 0.8656 - val_loss: 0.3332 - val_accuracy: 0.8625
# Epoch 90/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2549 - accuracy: 0.8599 - val_loss: 0.3200 - val_accuracy: 0.8591
# Epoch 91/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2519 - accuracy: 0.8637 - val_loss: 0.3254 - val_accuracy: 0.8634
# Epoch 92/110
# 207/207 [==============================] - 19s 94ms/step - loss: 0.2550 - accuracy: 0.8609 - val_loss: 0.3145 - val_accuracy: 0.8690
# Epoch 93/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2446 - accuracy: 0.8718 - val_loss: 0.3176 - val_accuracy: 0.8672
# Epoch 94/110
# 207/207 [==============================] - 19s 94ms/step - loss: 0.2496 - accuracy: 0.8662 - val_loss: 0.3298 - val_accuracy: 0.8457
# Epoch 95/110
# 207/207 [==============================] - 20s 94ms/step - loss: 0.2562 - accuracy: 0.8595 - val_loss: 0.3104 - val_accuracy: 0.8560
# Epoch 96/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2371 - accuracy: 0.8744 - val_loss: 0.3096 - val_accuracy: 0.8698
# Epoch 97/110
# 207/207 [==============================] - 19s 94ms/step - loss: 0.2423 - accuracy: 0.8648 - val_loss: 0.3575 - val_accuracy: 0.8522
# Epoch 98/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.2563 - accuracy: 0.8639 - val_loss: 0.3347 - val_accuracy: 0.8621
# Epoch 99/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.2603 - accuracy: 0.8593 - val_loss: 0.3130 - val_accuracy: 0.8685
# Epoch 100/110
# 207/207 [==============================] - 20s 96ms/step - loss: 0.2483 - accuracy: 0.8661 - val_loss: 0.3343 - val_accuracy: 0.8634
# Epoch 101/110
# 207/207 [==============================] - 18s 88ms/step - loss: 0.2643 - accuracy: 0.8627 - val_loss: 0.3142 - val_accuracy: 0.8569
# Epoch 102/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2520 - accuracy: 0.8692 - val_loss: 0.3238 - val_accuracy: 0.8522
# Epoch 103/110
# 207/207 [==============================] - 18s 88ms/step - loss: 0.2471 - accuracy: 0.8642 - val_loss: 0.3099 - val_accuracy: 0.8578
# Epoch 104/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.2508 - accuracy: 0.8678 - val_loss: 0.3166 - val_accuracy: 0.8625
# Epoch 105/110
# 207/207 [==============================] - 20s 96ms/step - loss: 0.2526 - accuracy: 0.8683 - val_loss: 0.3393 - val_accuracy: 0.8414
# Epoch 106/110
# 207/207 [==============================] - 18s 86ms/step - loss: 0.2501 - accuracy: 0.8679 - val_loss: 0.3211 - val_accuracy: 0.8634
# Epoch 107/110
# 207/207 [==============================] - 20s 95ms/step - loss: 0.2479 - accuracy: 0.8656 - val_loss: 0.3261 - val_accuracy: 0.8655
# Epoch 108/110
# 207/207 [==============================] - 18s 87ms/step - loss: 0.2371 - accuracy: 0.8749 - val_loss: 0.3559 - val_accuracy: 0.8539
# Epoch 109/110
# 207/207 [==============================] - 18s 85ms/step - loss: 0.2464 - accuracy: 0.8680 - val_loss: 0.3423 - val_accuracy: 0.8513
# Epoch 110/110
# 207/207 [==============================] - 20s 96ms/step - loss: 0.2423 - accuracy: 0.8714 - val_loss: 0.3240 - val_accuracy: 0.8690

# %%
# Save the model
model.save("drowsiness_inceptionv4.h5")
model.save("drowsiness_inceptionv4.model")

# %%
# Plot accuracy and loss
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, "b", label="training accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(epochs, loss, "b", label="training loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.show()

# %%
# Make predictions and evaluate the model
y_true = np.argmax(y_test, axis=1)
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 73/73 [==============================] - 10s 61ms/step

# %%
# Confusion Matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Print the confusion matrix
print("Confusion Matrix:\n", confusion_mtx)
# Out:
# Confusion Matrix:
#  [[579   6   0   0]
#  [ 13 569   0   0]
#  [  0   0 487  79]
#  [  0   0 206 381]]

# %%
# Accuracy Score
accuracy = np.sum(y_true == y_pred_classes) / len(y_true)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8689655172413793

# %%
# Classification Report
from sklearn.metrics import classification_report
class_report = classification_report(y_true, y_pred_classes, target_names=labels)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Closed       0.98      0.99      0.98       585
#         Open       0.99      0.98      0.98       582
#         yawn       0.70      0.86      0.77       566
#      no_yawn       0.83      0.65      0.73       587
#
#     accuracy                           0.87      2320
#    macro avg       0.87      0.87      0.87      2320
# weighted avg       0.88      0.87      0.87      2320

# %%
# Compute ROC curves and AUC for each class
n_classes = 4
fpr = dict()
tpr = dict()

roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curves for each class
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label='Class {} (AUC = {:.2f})'.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
